# %%
import pandas as pd

df = pd.read_csv("student_marks.csv")

df
# Out:
#      Name  Math  Science  English
# 0   Rahul    85       90       88
# 1   Priya    92       95       91
# 2   Arjun    78       82       80
# 3   Sneha    88       86       90
# 4   Kiran    95       98       97
# 5  Anjali    80       84       85

# %%
df["Total"] = df["Math"] + df["Science"] + df["English"]

df["Average"] = df["Total"] / 3

df
# Out:
#      Name  Math  Science  English  Total    Average
# 0   Rahul    85       90       88    263  87.666667
# 1   Priya    92       95       91    278  92.666667
# 2   Arjun    78       82       80    240  80.000000
# 3   Sneha    88       86       90    264  88.000000
# 4   Kiran    95       98       97    290  96.666667
# 5  Anjali    80       84       85    249  83.000000

# %%
top_student = df.loc[df["Total"].idxmax()]

print("Top Student:")
print(top_student)
# Out:
# Top Student:
# Name           Kiran
# Math              95
# Science           98
# English           97
# Total            290
# Average    96.666667
# Name: 4, dtype: object

# %%
import matplotlib.pyplot as plt

plt.bar(df["Name"], df["Total"])
plt.title("Student Total Marks")
plt.xlabel("Students")
plt.ylabel("Total Marks")

plt.show()

# %%
print("Highest Average Marks:")
print(df.loc[df["Average"].idxmax()])
# Out:
# Highest Average Marks:
# Name           Kiran
# Math              95
# Science           98
# English           97
# Total            290
# Average    96.666667
# Name: 4, dtype: object

# %%
print("Conclusion")
print("1. Kiran scored the highest total marks.")
print("2. Kiran achieved the highest average marks.")
print("3. All students performed well across subjects.")
print("4. Data analysis helps identify trends and top performers.")
# Out:
# Conclusion
# 1. Kiran scored the highest total marks.
# 2. Kiran achieved the highest average marks.
# 3. All students performed well across subjects.
# 4. Data analysis helps identify trends and top performers.
